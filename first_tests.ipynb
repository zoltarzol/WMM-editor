# %%
import pandas as pd
import libxml2

DATA_FOLDER = "./data/"
SAMPLE_FILE = "sample.wlmp"

df = pd.read_xml(DATA_FOLDER+SAMPLE_FILE)

df.head(10)
# Out:
#    MediaItem  ImageClip  TitleClip  AudioClip  ExtentSelector  \
# 0        NaN        NaN        NaN        NaN             NaN
# 1        NaN        NaN        NaN        NaN             NaN
# 2        NaN        NaN        NaN        NaN             NaN
# 3        NaN        NaN        NaN        NaN             NaN
# 4        NaN        NaN        NaN        NaN             NaN
#
#    BoundPlaceholder  BoundPropertyFloatSet  BoundPropertyFloat  themeID  \
# 0               NaN                    NaN                 NaN      NaN
# 1               NaN                    NaN                 NaN      NaN
# 2               NaN                    NaN                 NaN      NaN
# 3               NaN                    NaN                 NaN      NaN
# 4               NaN                    NaN                 NaN      0.0
#
#    MonolithicThemeOperations
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# ...
